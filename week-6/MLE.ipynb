# %% [markdown]
# ### Arg max

# %% [markdown]
# Consider what's the max of the function:
#
# $f(x) = -x^2 + 100$
#
# $\underset{x}{\arg\max} f(x) = -x^2 + 100$
#
# * Instead of giving me the value that was maximized, give me the value of arg max

# %% [markdown]
# ### Properties of the log function
#
# * How to understand the log function.
#
#
# $\log_{10}(100)$
#
# $ y = \ln (x) $
#
# * y is the power that we raise e to, to get to x

# %%
import numpy as np
import matplotlib.pyplot as plt

log_inputs = np.arange(0, 10)
log_outputs = np.log(log_x_values)
plt.plot(log_inputs, log_outputs)
# Out:
# /Users/flatironschool/anaconda/lib/python3.5/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """

# %% [markdown]
# #### Logs and Algebra
#
# * $\log(ab) = \log(a) + \log(b) $
# * $\log(a^b) = b \log(a)$
#
# #### Logs and calculus
#
# $\frac{\delta}{\delta x} ln(x) = 1/x $

# %% [markdown]
# ### Arg max and the log

# %% [markdown]
# * It's monotonic meaning that it only goes up
# * And if you have something that is monotonic, then if x > y then log x > log y

# %% [markdown]
# import numpy as np
# import matplotlib.pyplot as plt
#
# log_inputs = np.arange(0, 10)
# log_outputs = np.log(log_x_values)
# plt.plot(log_inputs, log_outputs)

# %%
def negative_x_squared_plus_100(x):
    return -x**2 + 100

y_values = negative_x_squared_plus_100(np.arange(-10, 10))
x_values = np.arange(-10, 10)

plt.plot(x_values, y_values)

# %%
logged_y_values = np.log(y_values)
plt.plot(x_values, logged_y_values)
# Out:
# /Users/flatironschool/anaconda/lib/python3.5/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# So it is not true that the max of f(x) equals the max of log f(x), but the arg max is the same.

# %% [markdown]
# ### Review probability density functions
#
# * So use to review a probability density function and that given a value, returns to us the probability.
#
# $f(x|p) = 1/p$
#
# * So far, what we have done is provide a probability.

# %% [markdown]
# ### Onto mle

# %% [markdown]
# * $X_i$ is a sample from density function $f(Xi | \theta)$
# *  So we choose our parameters by selecting the data that we observe the most likely
# * So then it $L(\theta) = \prod f(x_i|\theta) $
# * $\underset{\theta}{\arg\max} LL(\theta) = \underset{\theta}{\arg\max} L(\theta)$

# %% [markdown]
# * So then it $L(\theta) = \prod f(x_i|\theta) = \sum \log f(x_i|\theta) $

# %% [markdown]
# ### Steps
#
# 1. Need a formula for log likelihood, $LL(\theta)$
# 2. Need value of theta maximize the likelihood of a function
#     * $\frac{\delta LL(\theta)}{\delta \theta} = 0$

# %% [markdown]
# * [Derivation bernoulli and normalm](https://onlinecourses.science.psu.edu/stat414/node/191/)
